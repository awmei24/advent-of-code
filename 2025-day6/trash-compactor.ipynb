# %% [markdown]
# ## Day 6: Trash Compactor
# ### Part 1
#
# After helping the Elves in the kitchen, you were taking a break and helping them re-enact a movie scene when you over-enthusiastically jumped into the garbage chute!
#
# A brief fall later, you find yourself in a garbage smasher. Unfortunately, the door's been magnetically sealed.
#
# As you try to find a way out, you are approached by a family of cephalopods! They're pretty sure they can get the door open, but it will take some time. While you wait, they're curious if you can help the youngest cephalopod with her math homework.
#
# Cephalopod math doesn't look that different from normal math. The math worksheet (your puzzle input) consists of a list of problems; each problem has a group of numbers that need to be either added (+) or multiplied (*) together.
#
# **_However, the problems are arranged a little strangely; they seem to be presented next to each other in a very long horizontal list. For example_**:
#
# - 123 328  51 64
# -  45 64  387 23
# -   6 98  215 314
# - x +   x   +
#
# Each problem's numbers are arranged vertically; at the bottom of the problem is the symbol for the operation that needs to be performed. Problems are separated by a full column of only spaces. The left/right alignment of numbers within each problem can be ignored.
#
# **_So, this worksheet contains four problems_**:
#
# - 123 * 45 * 6 = 33210
# - 328 + 64 + 98 = 490
# - 51 * 387 * 215 = 4243455
# - 64 + 23 + 314 = 401
#
# To check their work, cephalopod students are given the grand total of adding together all of the answers to the individual problems. In this worksheet, the grand total is 33210 + 490 + 4243455 + 401 = 4277556.
#
# Of course, the actual worksheet is much wider. You'll need to make sure to unroll it completely so that you can read the problems clearly.
#
# Solve the problems on the math worksheet. What is the grand total found by adding together all of the answers to the individual problems?

# %%
with open('test_input.txt', 'r') as f: 
    test_rows = []
    for line in f: 
        test_rows.append(line.strip())
    
    updated_test_rows = []
    for test_row in test_rows: 
        updated_test_row = []
        split_test_row = test_row.split(' ')
        for element in split_test_row: 
            if element: 
                updated_test_row.append(element)

        updated_test_rows.append(updated_test_row)

updated_test_rows
# Out:
# [['123', '328', '51', '64'],
#  ['45', '64', '387', '23'],
#  ['6', '98', '215', '314'],
#  ['*', '+', '*', '+']]

# %%
import pandas as pd

def get_grand_total(updated_rows):
    def get_sum(values): 
        out = 0
        for value in values: 
            out += int(value)
        
        return out

    def get_product(values): 
        out = 1
        for value in values: 
            out *= int(value)
        
        return out

    col_list = []
    for i in range(len(updated_rows[0])): 
        col_list.append(f'P{i}')

    df = pd.DataFrame(updated_rows, columns=col_list)

    final_sum = 0
    for problem_col in df: 
        problem = df[problem_col].tolist()

        if problem[-1] == '+': 
            answer = get_sum(problem[:-1])
        
        if problem[-1] == '*': 
            answer = get_product(problem[:-1])
        
        final_sum += answer

    return final_sum

# %%
get_grand_total(updated_test_rows)
# Out:
# 4277556

# %%
with open('input.txt', 'r') as f: 
    rows = []
    for line in f: 
        rows.append(line.strip())
    
    updated_rows = []
    for row in rows: 
        updated_row = []
        split_row = row.split(' ')
        for element in split_row: 
            if element: 
                updated_row.append(element)

        updated_rows.append(updated_row)

get_grand_total(updated_rows)
# Out:
# 3968933219902

# %% [markdown]
# ### Part 2
# The big cephalopods come back to check on how things are going. When they see that your grand total doesn't match the one expected by the worksheet, they realize they forgot to explain how to read cephalopod math.
#
# Cephalopod math is written right-to-left in columns. Each number is given in its own column, with the most significant digit at the top and the least significant digit at the bottom. (Problems are still separated with a column consisting only of spaces, and the symbol at the bottom of the problem is still the operator to use.)
#
# **_Here's the example worksheet again_**:
#
# - 123 328  51 64
# -  45 64  387 23
# -   6 98  215 314
# - x +   x   +
#
# **_Reading the problems right-to-left one column at a time, the problems are now quite different_**:
#
# The rightmost problem is 4 + 431 + 623 = 1058
# The second problem from the right is 175 * 581 * 32 = 3253600
# The third problem from the right is 8 + 248 + 369 = 625
# Finally, the leftmost problem is 356 * 24 * 1 = 8544
#
# Now, the grand total is 1058 + 3253600 + 625 + 8544 = 3263827.
#
# Solve the problems on the math worksheet again. What is the grand total found by adding together all of the answers to the individual problems?

# %%
with open('test_input.txt', 'r') as f: 
    test_rows = []
    for line in f: 
        test_rows.append(line)

test_raw_operators = test_rows[-1]
test_raw_operators = test_raw_operators.split(' ')

test_operators = []
for element in test_raw_operators: 
    if element: 
        test_operators.append(element)

print(test_operators)

test_all_numbers = []
for i in range(len(test_rows[0])): 
    current_number = ''.join([test_rows[j][i] for j in range(3)])

    test_all_numbers.append(current_number.strip())

test_problems = [test_all_numbers[i:i+3] for i in range(0, len(test_all_numbers), 4)]
test_problems
# Out:
# ['*', '+', '*', '+']
# [['1', '24', '356'],
#  ['369', '248', '8'],
#  ['32', '581', '175'],
#  ['623', '431', '4']]

# %%
def get_sum(values): 
    out = 0
    for value in values: 
        if not value: 
            continue
        out += int(value)
    
    return out

def get_product(values): 
    out = 1
    for value in values:
        if not value: 
            continue
        out *= int(value)
    
    return out

# %%
with open('input.txt', 'r') as f: 
    rows = []
    for line in f: 
        rows.append(line)

raw_operators = rows[-1]
raw_operators = raw_operators.split(' ')

operators = []
for element in raw_operators: 
    if element: 
        operators.append(element)

all_numbers = []
for i in range(len(rows[0])): 
    current_number = ''.join([rows[j][i] for j in range(4)])

    all_numbers.append(current_number.strip())

joined_numbers = '|'.join(all_numbers)
# print(joined_numbers)
joined_problems = joined_numbers.split('||')
# print(joined_problems)

problems = []
for i, problem in enumerate(joined_problems):
    problems.append(problem.split('|'))

final_sum = 0
for i, problem in enumerate(problems): 
    # print(problem, operators[i])

    if operators[i] == '+': 
        answer = get_sum(problem)
    
    if operators[i] == '*': 
        answer = get_product(problem)

    # print(answer)
    final_sum += answer

final_sum
# get_grand_total_cephalopod(problems, operators)
# Out:
# 6019576291014
